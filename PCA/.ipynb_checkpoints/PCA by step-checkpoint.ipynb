# %% [markdown]
# # Create Data for PCA

# %%
import numpy as np
import math
np.random.seed(4294967295) # random seed for consistency

mu_vec1 = np.array(30 * [0]) #number of samples
cov_mat1 = np.identity(30) # number of samples
class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20) # number of features
# class1_sample *= 10

# %%
# %pylab inline
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10   
ax.plot(class1_sample[0,:], class1_sample[1,:], class1_sample[2,:], 'o', markersize=8, color='blue', alpha=0.5, label='class1')

plt.title('Samples for class 1 (first 3 dim)')
ax.legend(loc='upper right')

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
all_samples = np.copy(class1_sample.T)
print 'sample data'
print np.shape(all_samples)
# Out:
# sample data
# (30, 20)

# %%
np.count_nonzero(all_samples)
# Out:
# 600

# %%
np.zeros((2,4))
# Out:
# array([[ 0.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  0.]])

# %%
np.array([[1,2,3,4],
          [4,5,6,7]])
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA as sklearnPCA

# %%
print shape(all_samples)
pca = sklearnPCA(n_components=10)
fitted = pca.fit(all_samples)
trans = pca.transform(all_samples)
print shape(trans)
# Out:
# (30, 20)
# (30, 10)

# %%
plt.plot(trans[:,0],trans[:,1], 'o', markersize=7, color='blue', alpha=0.5, label='class1')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('Transformed samples without dropout rate')

plt.show()

# %% [markdown]
# # Apply Drop Out Rate ($e^{-\lambda\mu^2}$) / Gaussian Noise

# %% [markdown]
# I believe the proper order is:
# 1. generate low dim data
# 2. add gaussian noise to low dim
# 3. project back to high dim and apply drop out rate

# %%
lmbda = -.5
mu = 2
p_0 = math.e**(lmbda * mu**2)
p_0
# Out:
# 0.1353352832366127

# %%
def drop_out(p):
    return np.random.binomial(1, p, 1)[0]

# %%
#s = np.random.binomial(1, p_0, 100000000)
#print sum(s)/100000000.0

# %%
t = all_samples
shape(t)[0]
# Out:
# 30

# %%
#gaussian noise
noise_m = .1 * np.random.randn(shape(all_samples)[0], shape(all_samples)[1])

# %% [markdown]
# # dropped out data

# %%
noise_drop_matrix = np.copy(all_samples) + np.copy(noise_m)

# %%
count = 0
for (i,j), value in numpy.ndenumerate(noise_drop_matrix):
    if (drop_out(p_0) == 1):
        count += 1
        if (i == 0):
            print i, j
        noise_drop_matrix[i,j] = 0
print count
# Out:
# 0 1
# 0 15
# 89

# %%
np.count_nonzero(noise_drop_matrix)
# Out:
# 511

# %%
# pca = sklearnPCA(n_components=3)
# fitted = pca.fit(all_samples.T)
# red = np.dot(all_samples.T - pca.mean_, pca.components_.T)
# original = np.dot(red, pca.components_) + pca.mean_
#shape(all_samples.T)
# shape(original)
#test
#np.allclose(pca.inverse_transform(pca.transform(all_samples.T)), all_samples.T)

# %%
noise_drop_matrix[0,:]
# Out:
# array([ 0.68155082,  0.        ,  0.88896088, -0.88069306,  1.05202985,
#         0.38248587,  0.6922758 ,  0.00544404, -1.62023182, -2.60762457,
#         0.82832559,  0.88934325,  1.02279252,  1.51985183,  0.50142663,
#         0.        ,  0.04414057,  0.15749823,  1.43132729,  1.04037393])

# %%
class1_sample.T[0,:]
# Out:
# array([ 0.64840867, -0.02745217,  0.89606188, -0.88834521,  1.03971848,
#         0.49791942,  0.81703954,  0.10393517, -1.66768645, -2.51133329,
#         0.90407857,  0.90808237,  0.86472496,  1.50204659,  0.44631919,
#        -0.26334146,  0.18122911, -0.03243661,  1.53485167,  1.19453625])

# %%
fitted1 = pca.fit(noise_drop_matrix)
noise_memes = pca.transform(noise_drop_matrix)

# %%
print "zeros in DROPPED matrix"
print len(noise_drop_matrix[0,:]) - np.count_nonzero(noise_drop_matrix[0,:])
print "zeros in NON DROPPED matrix"
print len(all_samples[0,:]) - np.count_nonzero(all_samples[0,:])
print "net zeros dropped in 1 dimension"
np.count_nonzero(all_samples[0,:]) - np.count_nonzero(noise_drop_matrix[0,:])
# Out:
# zeros in DROPPED matrix
# 2
# zeros in NON DROPPED matrix
# 0
# net zeros dropped in 1 dimension
# 2

# %% [markdown]
# # Visualization Check

# %%
# %pylab inline

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10   
ax.plot(all_samples[0,:], all_samples[1,:], all_samples[2,:], 'o', markersize=8, color='blue', alpha=0.5, label='class1')
ax.plot(noise_drop_matrix[0,:], noise_drop_matrix[1,:], noise_drop_matrix[2,:], 'o', markersize=8, color='red', alpha=0.5, label='class1')

plt.title('Ground Truth Data/Dropped Data')
ax.legend(loc='upper right')

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
axs = np.arange(0,4, .2)
len(axs)
# Out:
# 20

# %%
noise_drop_matrix[0,:]
# Out:
# array([ 0.68155082,  0.        ,  0.88896088, -0.88069306,  1.05202985,
#         0.38248587,  0.6922758 ,  0.00544404, -1.62023182, -2.60762457,
#         0.82832559,  0.88934325,  1.02279252,  1.51985183,  0.50142663,
#         0.        ,  0.04414057,  0.15749823,  1.43132729,  1.04037393])

# %%
all_samples[0,:]
# Out:
# array([ 0.64840867, -0.02745217,  0.89606188, -0.88834521,  1.03971848,
#         0.49791942,  0.81703954,  0.10393517, -1.66768645, -2.51133329,
#         0.90407857,  0.90808237,  0.86472496,  1.50204659,  0.44631919,
#        -0.26334146,  0.18122911, -0.03243661,  1.53485167,  1.19453625])

# %%
plt.plot(noise_drop_matrix[0,:],axs, 'o', markersize=7, color='blue', alpha=0.5, label='class1')
plt.plot(all_samples[0,:], axs, 'o', markersize=7, color='red', alpha=0.5, label='class2')

plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('Original Data set - first dim x first dim')


plt.show()

# %% [markdown]
# # PCA Visualization Check

# %%
plt.plot(noise_memes[:,0],noise_memes[:,1], 'o', markersize=7, color='blue', alpha=0.5, label='class1')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('Transformed samples WITH dropout rate PC1/PC2')

plt.show()

plt.plot(trans[:,0],trans[:,1], 'o', markersize=7, color='red', alpha=0.5, label='class1')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('Transformed samples WITHOUT dropout rate (PC1/PC2)')

plt.show()

# %%
plt.plot(noise_memes[:,1],noise_memes[:,2], 'o', markersize=7, color='blue', alpha=0.5, label='class1')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('Transformed samples WITH dropout rate PC2/PC3')

plt.show()

plt.plot(trans[:,1],trans[:,2], 'o', markersize=7, color='red', alpha=0.5, label='class1')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('Transformed samples WITHOUT dropout rate PC2/PC3')

plt.show()

# %%
print "number of dropped entities after PCA"
np.count_nonzero(trans[0,:]) - np.count_nonzero(noise_memes[0,:])
# Out:
# number of dropped entities after PCA
# 0

# %% [markdown]
# Note: no value in a principal component is 0, since that would lose a lot of variance

# %% [markdown]
# # Goal is to go from blue to red

# %%
plt.plot(noise_memes[:,0],noise_memes[:,1], 'o', markersize=7, color='blue', alpha=0.5, label='drop')
plt.plot(trans[:,0],trans[:,1], 'o', markersize=7, color='red', alpha=0.5, label='NONdrop')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('PC1/PC2')

plt.show()

# %%
#arbitrary
plt.plot(noise_memes[:,5],noise_memes[:,6], 'o', markersize=7, color='blue', alpha=0.5, label='drop')
plt.plot(trans[:,5],trans[:,6], 'o', markersize=7, color='red', alpha=0.5, label='NONdrop')
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.legend()
plt.title('PC6/PC7')

plt.show()

# %% [markdown]
# # GIVEN: corruped gene expression matrix, recover good gene expression matrix

# %%
ground_truth = np.copy(all_samples[4,:])
ground_truth
# Out:
# array([ 0.11388774, -0.57915937,  0.81850406, -1.22087171, -1.00729492,
#         0.03653883,  1.15387207, -1.08234084,  0.1661883 ,  0.49045816,
#         1.74344674, -0.34617607,  0.02878019, -0.08676787,  0.88770384,
#        -0.07331318, -0.86511594,  0.47939428, -0.6872781 , -1.14106803])

# %%
real_data = np.copy(noise_drop_matrix[4,:])
real_data
# Out:
# array([ 0.        , -0.73012194,  0.82341361, -1.16805676, -0.96630949,
#         0.        ,  1.26363471, -1.02247344,  0.27666713,  0.58001763,
#         1.75429764, -0.40501304,  0.05941509, -0.16836418,  0.87357694,
#        -0.17434069, -0.89050229,  0.30344099,  0.        ,  0.        ])

# %% [markdown]
# # Create a statistical model to correct for drop out rate
# things to note
#     1. when to add data? (dropped out data)
#     2. what that data should be?

# %%
all_samples[4,:]
# Out:
# array([ 0.11388774, -0.57915937,  0.81850406, -1.22087171, -1.00729492,
#         0.03653883,  1.15387207, -1.08234084,  0.1661883 ,  0.49045816,
#         1.74344674, -0.34617607,  0.02878019, -0.08676787,  0.88770384,
#        -0.07331318, -0.86511594,  0.47939428, -0.6872781 , -1.14106803])

# %%
noise_drop_matrix[4,:]
# Out:
# array([ 0.        , -0.73012194,  0.82341361, -1.16805676, -0.96630949,
#         0.        ,  1.26363471, -1.02247344,  0.27666713,  0.58001763,
#         1.75429764, -0.40501304,  0.05941509, -0.16836418,  0.87357694,
#        -0.17434069, -0.89050229,  0.30344099,  0.        ,  0.        ])

# %% [markdown]
# # Attempt at Kalman Filter
# A Kalman filter is an optimal estimator - ie infers parameters of interest from
# indirect, inaccurate and uncertain observations.
# http://faculty.washington.edu/eeholmes/Files/An_EM_algorithm.pdf
# A more accurate (non linear filter) - Kushner–Stratonovich filtering
#
# Expectation Maximization for missing data
# http://www.stats.ox.ac.uk/~steffen/teaching/fsmHT07/fsm407c.pdf
# Proposed Steps:
#     1. ???train to find distribution (supervised learning) for EM algorithm error fix (oxford)
#     2. apply kalman filter to get rid of gaussian noise + more?
#     3. use EM algorithm to correct
